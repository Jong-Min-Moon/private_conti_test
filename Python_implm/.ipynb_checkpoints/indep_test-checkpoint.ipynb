# %%
import torch
import itertools
from scipy.special import comb

class LDPIndepTester:
    def __init__(self, cuda_device):
        self.cuda_device = cuda_device

   
    def bin_separately(self, data_X, data_Y, kappa):
        return (
            self.bin(data_X, kappa),
            self.bin(data_Y, kappa)
            )

        
    def range_check(self, data):
        if (torch.sum(data.gt(1))).gt(0):
            print("check data range")
            return False
        elif (torch.sum(data.lt(0))).gt(0):
            print("check data range")
            return False
        else:
            return True

    def run_test_conti_data(self, B, data_Y, data_Z, kappa, alpha, gamma, discrete_noise = False):
        #0. data range check
        
        if not self.range_check(data_Y):
            return
        if not self.range_check(data_Z):
            return
        
        #1. bin
        n = data_Y.size(dim = 0)
        data_Y_binned, data_Z_binned = self.bin_separately(data_Y, data_Z, kappa)

        #2. privatize
        data_Y_priv, data_Z_priv, noise_var_Y, noise_var_Z = self.privatize_indep(
            data_Y = data_Y,
            data_Z = data_Z,
            alpha = alpha,
            discrete_noise = discrete_noise
        )
        
        #4 compute original u-stat
        ustatOriginal = self.u_stat_indep_matrix(data_Y_priv, data_Z_priv)

        print(f"original u-statistic:{ustatOriginal}")
        
        #permutation procedure
        permStats = torch.empty(B).to(self.cuda_device)
        
        for i in range(B):
            perm_stat_now = self.u_stat_indep_matrix(
                data_Y_priv,
                data_Z_priv[
                    torch.randperm(data_Z_priv.size(dim=0))],
                ).to(self.cuda_device)

            permStats[i] = perm_stat_now
            #print(perm_stat_now)
         
        
        p_value_proxy = (1 +
                         torch.sum(
                             torch.gt(input = permStats, other = ustatOriginal)
                         )
                        ) / (B + 1)
        
        
        print(f"p value proxy: {p_value_proxy}")
        
        return(p_value_proxy < gamma, noise_var_Y, noise_var_Z)#test result: TRUE = 1 = reject the null, FALSE = 0 = retain the null.

        
    def privatize_indep(self, data_Y, data_Z, alpha = float("inf"), discrete_noise = False):
        ## assume the data is discrete by nature or has already been dicretized.
        n = data_Y.size(dim = 0) # Y and Z have the same sample size.
        kappa_d1 = data_Y.size(dim = 1) #kappa^d if conti data, d if discrete data
        kappa_d2 = data_Z.size(dim = 1) #kappa^d if conti data, d if discrete data

        print(f"noise dimension : {kappa_d1}, {kappa_d2}")
        
        scale_factor = torch.tensor( (kappa_d1 * kappa_d2)**(1/2) )
        sigma_kappa_alpha = 4 * (2 ** (1/2)) * scale_factor / alpha
        
        if alpha == float("inf"): #non-private case
            return( torch.mul(scale_factor, data) )
        else:
            data_Y_priv, noise_var_Y = self.privatize_indep_separate(
                    data = data_Y,
                    scale_factor = scale_factor,
                    sigma_kappa_alpha = sigma_kappa_alpha,
                    discrete_noise = discrete_noise
            )
            data_Z_priv, noise_var_Z = self.privatize_indep_separate(
                    data = data_Z,
                    scale_factor = scale_factor,
                    sigma_kappa_alpha = sigma_kappa_alpha,
                    discrete_noise = discrete_noise
            )
        return(data_Y_priv, data_Z_priv, noise_var_Y, noise_var_Z)
        
    
    def privatize_indep_separate(self, data, scale_factor, sigma_kappa_alpha, discrete_noise):
        n = data.size(dim = 0)
        if discrete_noise:
            noise, noise_var = self.noise_conti(data, sigma_kappa_alpha) #fix here later
        else:
            noise, noise_var = self.noise_conti(data, sigma_kappa_alpha)
        return(   
            torch.add(
                input = noise.reshape(n, -1),
                alpha = scale_factor,
                other = data
            ), 
            noise_var
        )
                       
    def noise_conti(self, data, sigma_kappa_alpha):
        #dim = kappa^d for conti data, d for discrete data
        laplace_samples = self.generate_unit_laplace(data)
        laplace_samples = sigma_kappa_alpha * laplace_samples
        print("noise type: conti")
        return( laplace_samples, torch.var(laplace_samples) )
    

    def generate_unit_laplace(self, data):
        n = data.size(dim = 0)
        d = data.size(dim = 1)
        unit_laplace_generator = torch.distributions.laplace.Laplace(
            torch.tensor(0.0).to(self.cuda_device),
            torch.tensor(2**(-1/2)).to(self.cuda_device)
        )
        return unit_laplace_generator.sample(sample_shape = torch.Size([n * d]))

  



##########################################################################################
################# For binning ############################################################
##########################################################################################
    def bin(self, data, kappa): 
        ''' Only for continuous data'''
        
        # create designated number of intervals
        d = self.get_dimension(data)
     
        # 1. for each dimension, turn the continuous data into interval
        # each row now indicates a hypercube in [0,1]^d
        # the more the data is closer to 1, the larger the interval index.
        dataInterval = self.transform_bin_index(data = data, nIntervals = kappa)
        
        # 2. for each datapoint(row),
        #    turn the hypercube data into a multivariate data of (1, 2, ..., kappa^d)
        #    each row now becomes an integer.
        dataMultivariate = self.TransformMultivariate(
            dataInterval = dataInterval,
            nBin = kappa,
        )
        # 3. turn the indices into one-hot vectors
        dataOnehot = self.TransformOnehot(dataMultivariate, kappa**d)
        return(dataOnehot)
    
    def transform_bin_index(self, data, nIntervals):
        ''' Only for continuous data.
        for each dimension, transform the data in [0,1] into the interval index
        first interval = [0, x], the others = (y z]
        
        input arguments
            data: torch tensor object on GPU
            nIntervals: integer
        output
            dataIndices: torch tensor, dimension same as the input
        '''
        # create designated number of intervals
        d = self.get_dimension(data)
        breaks = torch.linspace(start = 0, end = 1, steps = nIntervals + 1).to(self.cuda_device) #floatTensor
        dataIndices = torch.bucketize(data, breaks, right = False) # ( ] form.
        dataIndices = dataIndices.add(
            dataIndices.eq(0)
        ) #move 0 values from the bin number 0 to the bin number 1        
        return(dataIndices)
    
    def TransformMultivariate(self, dataInterval, nBin):
        """Only for continuous and multivariate data ."""
        d = self.get_dimension(dataInterval)
        
        if d == 1:
            return(dataInterval.sub(1))
        else:
            exponent = torch.linspace(start = (d-1), end = 0, steps = d, dtype = torch.long)
            vector = torch.tensor(nBin).pow(exponent)
            return( torch.matmul( dataInterval.sub(1).to(torch.float), vector.to(torch.float).to(self.cuda_device) ).to(torch.long) )
    
    def TransformOnehot(self, dataMultivariate, newdim):
        return(
            torch.nn.functional.one_hot(
                dataMultivariate,
                num_classes = newdim)
        )
    
    
    def get_dimension(self, data):
        if data.dim() == 1:
            return(1)
        elif data.dim() == 2:
            return( data.size(dim = 1) )
        else:
            return # we only use up to 2-dimensional tensor, i.e. matrix
##########################################################################################
##########################################################################################


    
    
    def kernel_indep(self, fourchunk):
        ip = torch.matmul(fourchunk, torch.transpose(fourchunk, 0, 1))
        return(ip[0,1] + ip[2,3] - ip[0,2] - ip[1,3])

     
    def u_stat_indep_matrix(self, data_X, data_Y):
        n = data_X.size(dim=0)
        Phi = torch.matmul(data_X, torch.transpose(data_X, 0, 1))
        Psi = torch.matmul(data_Y, torch.transpose(data_Y, 0, 1))
        Phi_tilde = Phi.fill_diagonal_(0.0)
        Psi_tilde = Psi.fill_diagonal_(0.0)
        n_four = n * (n-1) * (n-2) * (n-3)
        one = torch.ones(n, 1).to(device)
        oneT = torch.transpose(one, 0, 1)

        PhiPsi = torch.matmul(Phi, Psi)
        trPhiPsi = torch.trace(PhiPsi)
        onePhiPsiOne = torch.matmul(oneT, torch.matmul(PhiPsi, one))

        onePhione = torch.matmul(oneT, torch.matmul(Phi, one))
        onePsione = torch.matmul(oneT, torch.matmul(Psi, one))
        onePhioneonePsione = torch.matmul(onePhione, onePsione)

        Un = (
          4 * (onePhioneonePsione - 4 * onePhiPsiOne + 2 * trPhiPsi)
        - 8 * (n-3) *(onePhiPsiOne - trPhiPsi)
        + 4 * (n-3)*(n-2) * trPhiPsi
        )
        
        return(Un/n_four)
    
    def u_stat_indep_original(self, data_X, data_Y):
        n = data_X.size(dim = 0)
        print(f"number of calculation = {2*scipy.special.comb(n,4) }")
        n_four = n * (n-1) * (n-2) * (n-3)
        U_statistic = 0
        for i in range(n):
            set_j = set(range(n)) - {i}
            for j in set_j:
                set_k = set_j - {j}
                for k in set_k:
                    set_r = set_k - {k}
                    for r in set_r:
                        comb = [i,j,k,r]
                        U_statistic = U_statistic + (
                            self.kernel_indep(data_X[comb,]) * self.kernel_indep(data_Y[comb,])
                        )/n_four
        return(U_statistic)

# %%
import scipy
device = torch.device('cuda:1')

n= 1000
d = 2
loc = torch.zeros(d)
scale = torch.ones(d)*2
mvn1 = torch.distributions.MultivariateNormal(loc, scale_tril=torch.diag(scale))
mvn2 = torch.distributions.MultivariateNormal(loc, scale_tril=torch.diag(scale))

data_Y = mvn1.sample(sample_shape=torch.Size([n])).to(device)
data_Y = data_Y.abs() / data_Y.abs().max()

data_Z = mvn2.sample(sample_shape=torch.Size([n])).to(device)
data_Z = data_Z.abs() / data_Z.abs().max()

tester = LDPIndepTester(device)
tester.run_test_conti_data(B = 300, data_Y = data_Y, data_Z = data_Z, kappa = 3, alpha = 0.5, gamma = 0.05, discrete_noise = False)
# Out:
# 2
# 2
# noise dimension : 2, 2
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-2381.4062]], device='cuda:1')
# p value proxy: 0.8272424936294556
# (tensor(False, device='cuda:1'),
#  tensor(482.5581, device='cuda:1'),
#  tensor(493.8383, device='cuda:1'))

# %% [markdown]
# dependent case

# %%
import scipy
device = torch.device('cuda:1')

n= 10
d = 2
loc = torch.zeros(d)
scale = torch.ones(d)*2
mvn1 = torch.distributions.MultivariateNormal(loc, scale_tril=torch.diag(scale))
mvn2 = torch.distributions.MultivariateNormal(loc, scale_tril=torch.diag(scale))

data_Y = mvn1.sample(sample_shape=torch.Size([n])).to(device)
data_Y = data_Y.abs() / data_Y.abs().max()

data_Z = data_Y

tester = LDPIndepTester(device)
tester.run_test_conti_data(B = 300, data_Y = data_Y, data_Z = data_Z, kappa = 3, alpha = 1, gamma = 0.05, discrete_noise = False)
# Out:
# 2
# 2
# noise dimension : 2, 2
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-15337.7109]], device='cuda:1')
# p value proxy: 0.6810631155967712
# (tensor(False, device='cuda:1'),
#  tensor(184.5706, device='cuda:1'),
#  tensor(100.3413, device='cuda:1'))

# %%
data_Y[[1,3,2]]
# Out:
# tensor([[0.0670, 0.0777],
#         [0.1383, 0.5785],
#         [0.0628, 0.2662]], device='cuda:1')

# %%
data_Y[[1,2,3]]
# Out:
# tensor([[0.1953, 0.3120],
#         [0.1027, 0.2393],
#         [0.0016, 0.1836]], device='cuda:1')

# %%
data_Y
# Out:
# tensor([[0.1848, 0.1545],
#         [0.1953, 0.3120],
#         [0.1027, 0.2393],
#         ...,
#         [0.0226, 0.4141],
#         [0.2555, 0.2850],
#         [0.4730, 0.1915]], device='cuda:1')

# %%
data_X = torch.transpose(torch.tensor([[1.0,2,3,4,5]]), 0, 1).to(device)
data_Y = torch.transpose(torch.tensor([[11.0,12,13,14,15]]), 0, 1).to(device)
print(matrix_form(data_X, data_Y))
tester.u_stat_indep(data_X, data_Y)
# Out:
# tensor([[20.6667]], device='cuda:1')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [181], in <cell line: 6>()
#       4 data_Y = torch.transpose(torch.tensor([[11.0,12,13,14,15]]), 0, 1).to(device)
#       5 print(matrix_form(data_X, data_Y))
# ----> 6 tester.u_stat_indep(data_X, data_Y)
#
# AttributeError: 'LDPIndepTester' object has no attribute 'u_stat_indep'

# %%
data_X = torch.ones(10,3).to(device)
data_Y = data_X
print(matrix_form(data_X, data_Y))
tester = LDPIndepTester(device)
tester.u_stat_indep(data_X, data_Y)
# Out:
# tensor([[0.]], device='cuda:1')
# number of calculation = 10.0
# tensor(0., device='cuda:1')

# %%
data_X = torch.transpose(torch.tensor([[1.0, 1, 1, 1, 1,2,3,4]]), 0, 1).to(device)
data_Y = data_X
print(matrix_form(data_X, data_Y))
print(tester.u_stat_indep(data_X, data_Y))
# Out:
# tensor([[5.2857]], device='cuda:1')
# number of calculation = 140.0
# tensor(5.2857, device='cuda:1')

# %%
data_X = torch.transpose(torch.tensor([
    [1.0, 12, 1, 1, 1,22,3,4],[1.0, 12, 1, 1, 1,22,3,4]]
), 0, 1).to(device)
data_Y = data_X-1
print(matrix_form(data_X, data_Y))
print(tester.u_stat_indep(data_X, data_Y))
# Out:
# tensor([[26567.0859]], device='cuda:1')
# number of calculation = 140.0
# tensor(26567.1289, device='cuda:1')

# %%
data_X = torch.transpose(torch.tensor([[1.0, 12, 1, 1, 1,12,33,2,1,3,4,5,7,4,5,3]]), 0, 1).to(device)
data_Y = data_X-10.0
print(matrix_form(data_X, data_Y))
print(tester.u_stat_indep(data_X, data_Y))
# Out:
# tensor([[6293.0815]], device='cuda:1')
# number of calculation = 3640.0
# tensor(6293.6973, device='cuda:1')

# %%
print("job started")
import time
import torch
import sys
import datetime
#sys.path.append("/mnt/nas/users/mjm/GitHub/private_conti_test/Python_implm/modules") 

# set seed number for reproducibility
torch.manual_seed(0)
import random
random.seed(0)
import numpy as np
np.random.seed(0)

#from tester import LDPTwoSampleTester

USE_CUDA = torch.cuda.is_available() 
print(f"cuda available: {USE_CUDA}")

device = torch.device('cuda:0' if USE_CUDA else 'cpu') 
print(f"code run on device:: {device}")


####CHANGE HERE#####
n = 100
####################
kappa = 3 #number of bins
alpha = 0.8 #privacy level
gamma = 0.05 # significance level
nTests = 500 #number of tests for power estimation
B = 300 # number of permutations
d_1 = 3
d_2 = 3

print(f"""
simulation started at = {datetime.datetime.now()} \n
n = {n},\n
kappa = {kappa}, alpha = {alpha},\n
gamma = {gamma}, nTests = {nTests},\n
B = {B}, d_1 = {d_1}, d_2 = {d_2}
""")

start_time = time.time()

copula_mean = torch.zeros(d_1+d_2).to(device)
sigma = (2.5 * torch.ones(d_1+d_2, d_1+d_2) + 2.5 * torch.eye(d_1+d_2)).to(device)

print("sigma")
print(sigma)

tester = LDPIndepTester(device)
generator_YZ = torch.distributions.multivariate_normal.MultivariateNormal(
    loc = copula_mean, 
    covariance_matrix = sigma)

cdf_calculator = torch.distributions.normal.Normal(loc = 0.0, scale = 1.0)

test_results = torch.empty(nTests)
noise_vars_Y = torch.empty(nTests)
noise_vars_Z = torch.empty(nTests)

for rep in range(nTests):
    print(f"\n{rep+1}th run")
    
    data_yz = cdf_calculator.cdf(generator_YZ.sample((n,)))   
    
    test_results[rep], noise_vars_Y[rep], noise_vars_Z[rep] = tester.run_test_conti_data(
        B,
        data_yz[:,range(d_1)],
        data_yz[:,range(d_1, d_1+d_2)],
        kappa, alpha, gamma,
        #################
        discrete_noise = False
        ###############
        )
    print(f"result: {test_results[rep]}")
    print(f"power_upto_now: { torch.sum(test_results[:(rep+1)])/(rep+1) }")

    print(f"noise variance for Y: {noise_vars_Y[rep]}")
    print(f"average noise variance for Y upto now: { torch.sum(noise_vars_Y[:(rep+1)])/(rep+1) }")
    
    print(f"noise variance for Z: {noise_vars_Z[rep]}")
    print(f"average noise variance for Z upto now: { torch.sum(noise_vars_Z[:(rep+1)])/(rep+1) }")
  
print( f"power estimate : { torch.sum(test_results)/nTests }" )
print( f"elapsed time: { time.time() - start_time }" )
print( f"simulation ended at {datetime.datetime.now()}" )
# Out:
# job started
# cuda available: True
# code run on device:: cuda:0
#
# simulation started at = 2022-07-09 17:01:36.054668
#
# n = 100,
#
# kappa = 3, alpha = 0.8,
#
# gamma = 0.05, nTests = 500,
#
# B = 300, d_1 = 3, d_2 = 3
#
# sigma
# tensor([[5.0000, 2.5000, 2.5000, 2.5000, 2.5000, 2.5000],
#         [2.5000, 5.0000, 2.5000, 2.5000, 2.5000, 2.5000],
#         [2.5000, 2.5000, 5.0000, 2.5000, 2.5000, 2.5000],
#         [2.5000, 2.5000, 2.5000, 5.0000, 2.5000, 2.5000],
#         [2.5000, 2.5000, 2.5000, 2.5000, 5.0000, 2.5000],
#         [2.5000, 2.5000, 2.5000, 2.5000, 2.5000, 5.0000]], device='cuda:0')
#
# 1th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-2080.4893]], device='cuda:0')
# p value proxy: 0.4883720874786377
# result: 0.0
# power_upto_now: 0.0
# noise variance for Y: 434.619873046875
# average noise variance for Y upto now: 434.619873046875
# noise variance for Z: 426.7673645019531
# average noise variance for Z upto now: 426.7673645019531
#
# 2th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[7493.0854]], device='cuda:0')
# p value proxy: 0.3521594703197479
# result: 0.0
# power_upto_now: 0.0
# noise variance for Y: 417.3288879394531
# average noise variance for Y upto now: 425.974365234375
# noise variance for Z: 416.5580749511719
# average noise variance for Z upto now: 421.6627197265625
#
# 3th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[16153.7725]], device='cuda:0')
# p value proxy: 0.3488371968269348
# result: 0.0
# power_upto_now: 0.0
# noise variance for Y: 546.1775512695312
# average noise variance for Y upto now: 466.0420837402344
# noise variance for Z: 546.6488037109375
# average noise variance for Z upto now: 463.3247375488281
#
# 4th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-40122.2031]], device='cuda:0')
# p value proxy: 0.9534883499145508
# result: 0.0
# power_upto_now: 0.0
# noise variance for Y: 411.4384765625
# average noise variance for Y upto now: 452.39117431640625
# noise variance for Z: 383.249755859375
# average noise variance for Z upto now: 443.3059997558594
#
# 5th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-8063.9775]], device='cuda:0')
# p value proxy: 0.5880398750305176
# result: 0.0
# power_upto_now: 0.0
# noise variance for Y: 301.6794738769531
# average noise variance for Y upto now: 422.24884033203125
# noise variance for Z: 441.12164306640625
# average noise variance for Z upto now: 442.869140625
#
# 6th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[24934.5918]], device='cuda:0')
# p value proxy: 0.262458473443985
# result: 0.0
# power_upto_now: 0.0
# noise variance for Y: 414.1612548828125
# average noise variance for Y upto now: 420.9009094238281
# noise variance for Z: 477.12384033203125
# average noise variance for Z upto now: 448.5782470703125
#
# 7th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-20623.0723]], device='cuda:0')
# p value proxy: 0.8205980062484741
# result: 0.0
# power_upto_now: 0.0
# noise variance for Y: 369.2113952636719
# average noise variance for Y upto now: 413.5166931152344
# noise variance for Z: 415.59124755859375
# average noise variance for Z upto now: 443.8658142089844
#
# 8th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-48634.5820]], device='cuda:0')
# p value proxy: 0.9734219312667847
# result: 0.0
# power_upto_now: 0.0
# noise variance for Y: 442.74566650390625
# average noise variance for Y upto now: 417.1702880859375
# noise variance for Z: 449.6432800292969
# average noise variance for Z upto now: 444.5880126953125
#
# 9th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-34606.2695]], device='cuda:0')
# p value proxy: 0.8205980062484741
# result: 0.0
# power_upto_now: 0.0
# noise variance for Y: 429.93780517578125
# average noise variance for Y upto now: 418.58892822265625
# noise variance for Z: 494.7596130371094
# average noise variance for Z upto now: 450.1626281738281
#
# 10th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-10473.5410]], device='cuda:0')
# p value proxy: 0.5880398750305176
# result: 0.0
# power_upto_now: 0.0
# noise variance for Y: 452.54364013671875
# average noise variance for Y upto now: 421.984375
# noise variance for Z: 453.2752990722656
# average noise variance for Z upto now: 450.473876953125
#
# 11th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-38616.4648]], device='cuda:0')
# p value proxy: 0.8006644248962402
# result: 0.0
# power_upto_now: 0.0
# noise variance for Y: 609.5884399414062
# average noise variance for Y upto now: 439.0392761230469
# noise variance for Z: 469.791748046875
# average noise variance for Z upto now: 452.2300109863281
#
# 12th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-9969.5371]], device='cuda:0')
# p value proxy: 0.6245846748352051
# result: 0.0
# power_upto_now: 0.0
# noise variance for Y: 448.2792663574219
# average noise variance for Y upto now: 439.8092956542969
# noise variance for Z: 386.38726806640625
# average noise variance for Z upto now: 446.7431335449219
#
# 13th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-62255.4766]], device='cuda:0')
# p value proxy: 0.9667773842811584
# result: 0.0
# power_upto_now: 0.0
# noise variance for Y: 528.2749633789062
# average noise variance for Y upto now: 446.61431884765625
# noise variance for Z: 484.6974792480469
# average noise variance for Z upto now: 449.6627502441406
#
# 14th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-32428.3613]], device='cuda:0')
# p value proxy: 0.9169434905052185
# result: 0.0
# power_upto_now: 0.0
# noise variance for Y: 395.0109558105469
# average noise variance for Y upto now: 442.92840576171875
# noise variance for Z: 404.40374755859375
# average noise variance for Z upto now: 446.429931640625
#
# 15th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-24955.1660]], device='cuda:0')
# p value proxy: 0.7840531468391418
# result: 0.0
# power_upto_now: 0.0
# noise variance for Y: 495.5079345703125
# average noise variance for Y upto now: 446.4337158203125
# noise variance for Z: 439.0641784667969
# average noise variance for Z upto now: 445.93890380859375
#
# 16th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[92511.5469]], device='cuda:0')
# p value proxy: 0.019933555275201797
# result: 1.0
# power_upto_now: 0.0625
# noise variance for Y: 398.8438415527344
# average noise variance for Y upto now: 443.4593505859375
# noise variance for Z: 482.89105224609375
# average noise variance for Z upto now: 448.24835205078125
#
# 17th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-10686.2383]], device='cuda:0')
# p value proxy: 0.6245846748352051
# result: 0.0
# power_upto_now: 0.05882352963089943
# noise variance for Y: 508.32293701171875
# average noise variance for Y upto now: 447.27484130859375
# noise variance for Z: 366.28253173828125
# average noise variance for Z upto now: 443.4268798828125
#
# 18th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-42954.]], device='cuda:0')
# p value proxy: 0.9102990031242371
# result: 0.0
# power_upto_now: 0.0555555559694767
# noise variance for Y: 446.37799072265625
# average noise variance for Y upto now: 447.2250061035156
# noise variance for Z: 461.22015380859375
# average noise variance for Z upto now: 444.4153747558594
#
# 19th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-59010.1680]], device='cuda:0')
# p value proxy: 1.0
# result: 0.0
# power_upto_now: 0.05263157933950424
# noise variance for Y: 433.65118408203125
# average noise variance for Y upto now: 446.5106506347656
# noise variance for Z: 450.9970703125
# average noise variance for Z upto now: 444.76177978515625
#
# 20th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-36565.4062]], device='cuda:0')
# p value proxy: 0.8338870406150818
# result: 0.0
# power_upto_now: 0.05000000074505806
# noise variance for Y: 525.5751342773438
# average noise variance for Y upto now: 450.4638671875
# noise variance for Z: 450.5107727050781
# average noise variance for Z upto now: 445.0492248535156
#
# 21th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-9076.0703]], device='cuda:0')
# p value proxy: 0.6146179437637329
# result: 0.0
# power_upto_now: 0.0476190485060215
# noise variance for Y: 382.4248046875
# average noise variance for Y upto now: 447.2239074707031
# noise variance for Z: 388.785400390625
# average noise variance for Z upto now: 442.3699645996094
#
# 22th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-45748.1953]], device='cuda:0')
# p value proxy: 0.9435215592384338
# result: 0.0
# power_upto_now: 0.04545454680919647
# noise variance for Y: 423.4313659667969
# average noise variance for Y upto now: 446.1424560546875
# noise variance for Z: 461.2326965332031
# average noise variance for Z upto now: 443.2274169921875
#
# 23th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[10836.9238]], device='cuda:0')
# p value proxy: 0.3720930218696594
# result: 0.0
# power_upto_now: 0.043478261679410934
# noise variance for Y: 485.5093078613281
# average noise variance for Y upto now: 447.8540344238281
# noise variance for Z: 397.9599609375
# average noise variance for Z upto now: 441.2592468261719
#
# 24th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[67302.5547]], device='cuda:0')
# p value proxy: 0.039867110550403595
# result: 1.0
# power_upto_now: 0.0833333358168602
# noise variance for Y: 451.4190979003906
# average noise variance for Y upto now: 448.0025634765625
# noise variance for Z: 448.4924621582031
# average noise variance for Z upto now: 441.5606384277344
#
# 25th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[20544.8887]], device='cuda:0')
# p value proxy: 0.2259136140346527
# result: 0.0
# power_upto_now: 0.07999999821186066
# noise variance for Y: 402.22698974609375
# average noise variance for Y upto now: 446.17156982421875
# noise variance for Z: 531.3766479492188
# average noise variance for Z upto now: 445.1532287597656
#
# 26th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-312.9049]], device='cuda:0')
# p value proxy: 0.41528236865997314
# result: 0.0
# power_upto_now: 0.07692307978868484
# noise variance for Y: 462.83367919921875
# average noise variance for Y upto now: 446.81243896484375
# noise variance for Z: 412.763427734375
# average noise variance for Z upto now: 443.9075012207031
#
# 27th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[8373.6445]], device='cuda:0')
# p value proxy: 0.35880398750305176
# result: 0.0
# power_upto_now: 0.07407407462596893
# noise variance for Y: 480.439697265625
# average noise variance for Y upto now: 448.0578308105469
# noise variance for Z: 516.4395141601562
# average noise variance for Z upto now: 446.5938720703125
#
# 28th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-25212.7500]], device='cuda:0')
# p value proxy: 0.8106312155723572
# result: 0.0
# power_upto_now: 0.0714285746216774
# noise variance for Y: 491.6167297363281
# average noise variance for Y upto now: 449.6134948730469
# noise variance for Z: 352.3145751953125
# average noise variance for Z upto now: 443.22674560546875
#
# 29th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-11641.0635]], device='cuda:0')
# p value proxy: 0.594684362411499
# result: 0.0
# power_upto_now: 0.06896551698446274
# noise variance for Y: 475.94195556640625
# average noise variance for Y upto now: 450.5213928222656
# noise variance for Z: 581.9950561523438
# average noise variance for Z upto now: 448.0118103027344
#
# 30th run
# 3
# 3
# noise dimension : 3, 3
# noise type: conti
# noise type: conti
# original u-statistic:tensor([[-3859.2485]], device='cuda:0')

# %%
data_yz.gt(1).sum()
# Out:
# tensor(0, device='cuda:0')

# %%
data_yz.le(0).sum()
# Out:
# tensor(3, device='cuda:0')
